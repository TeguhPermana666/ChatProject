# %%
import requests
import json

# URL API Call yang digunakan untuk mengirim dan menerima pesan
BASE_URL = "http://127.0.0.1:5000"

# Fungsi untuk mengirim pesan chat ke server
def send_message(user, message):
    url = f"{BASE_URL}/chat" 
    data = {"user": user, "message": message}
    
    response = requests.post(url, json=data)
    
    if response.status_code == 200:
        try:
            return response.json()  # Return JSON Response
        except json.JSONDecodeError:
            return {"error": "Invalid JSON response from server"}
    else:
        return {"error": f"Server returned status code {response.status_code}"}

# Fungsi untuk mendapatkan ringkasan chat dari log percakapan
def get_summary(user):
    url = f"{BASE_URL}/summary"
    params = {"user": user}

    response = requests.get(url, params=params)

    if response.status_code == 200:
        try:
            return response.json()  # Return JSON Response
        except json.JSONDecodeError:
            return {"error": "Invalid JSON response from server"}
    else:
        return {"error": f"Server returned status code {response.status_code}"}

# Pesan spesifik untuk setiap user (Flow Chat untuk masing-masing user dengan konteks konsultasi AI)
user_messages = {
    "Andi": [
        "Halo, saya Andi. Saya ingin mengembangkan model deep learning untuk segmentasi gambar medis.",
        "Apa arsitektur terbaik untuk segmentasi MRI? Apakah U-Net sudah cukup baik?",
        "Bagaimana cara meningkatkan akurasi model saya? Apakah ada teknik augmentasi yang direkomendasikan?"
    ],
    "Budi": [
        "Hai, saya Budi. Saya sedang mengerjakan proyek NLP dan ingin memahami bagaimana fine-tuning model BERT.",
        "Apakah saya perlu banyak data untuk fine-tuning BERT agar mendapatkan hasil optimal?",
        "Bagaimana cara mengatasi overfitting pada model NLP saya?"
    ],
    "Citra": [
        "Selamat siang, saya Citra. Saya ingin memahami bagaimana cara mendeteksi anomali pada data time series.",
        "Apakah Autoencoder cocok untuk mendeteksi anomali pada data keuangan?",
        "Bagaimana cara memilih threshold terbaik untuk mendeteksi anomali?"
    ],
    "Anom":[
        "Selamat Sorem, Saya Anom. Saya ingin melakukan konsultasi mengenai http://cabcode.id/",
        "Apa saja yang dapat dilakukan oleh http://cabcode.id/?",
        "Saya ingin memesan layanan Konsultasi dan tutor di http://cabcode.id/, kiranya layanan seperti apakah itu"
    ]
}

# Simulasi percakapan dengan AI Consultant untuk masing-masing user
for user, messages in user_messages.items():
    print(f"\n--- Konsultasi AI dengan {user} ---")
    
    for message in messages:
        response = send_message(user, message)
        reply = response.get("reply", response.get("error"))
        print(f"{user}: {message}")
        print(f"AI Consultant: {reply}\n")

# Menampilkan ringkasan konsultasi masing-masing user
for user in user_messages.keys():
    print(f"\n--- Ringkasan konsultasi {user} ---")
    response = get_summary(user)
    print(response.get("summary", response.get("error")))
# Out:
# --- Konsultasi AI dengan Andi ---
# Andi: Halo, saya Andi. Saya ingin mengembangkan model deep learning untuk segmentasi gambar medis.
# AI Consultant: Halo Andi, apakah Anda memiliki pertanyaan spesifik atau butuh bantuan dalam pengembangan model deep learning untuk segmentasi gambar medis? Silahkan beri saya informasi lebih detail agar saya dapat memberikan bantuan yang lebih tepat.
#
# Andi: Apa arsitektur terbaik untuk segmentasi MRI? Apakah U-Net sudah cukup baik?
# AI Consultant: Halo Andi, untuk segmentasi gambar medis seperti MRI, U-Net memang merupakan salah satu arsitektur yang sudah terbukti efektif dan umum digunakan. Namun, untuk memastikan bahwa model yang Anda kembangkan sesuai dengan kebutuhan spesifik Anda, disarankan untuk melakukan eksperimen dan evaluasi lebih lanjut terhadap berbagai arsitektur lainnya yang mungkin lebih cocok. Terutama, pertimbangkan karakteristik data gambar medis MRI yang Anda miliki dan pertimbangkan apakah terdapat arsitektur lain yang dapat lebih memaksimalkan performa segmentasi untuk kasus penggunaan Anda. Jika Anda membutuhkan bantuan dalam mengevaluasi atau membandingkan arsitektur-arsitektur tersebut, silakan berbicara lebih detail agar saya dapat memberikan bantuan yang lebih spesifik.
#
# Andi: Bagaimana cara meningkatkan akurasi model saya? Apakah ada teknik augmentasi yang direkomendasikan?
# AI Consultant: Untuk meningkatkan akurasi model Anda, selain menggunakan teknik augmentasi data seperti rotasi, pergeseran, zoom, flipping, dan perubahan warna, Anda juga dapat mempertimbangkan teknik lain seperti cutout, random erasing, atau random cropping untuk memperkenalkan variasi tambahan pada data latihan. Selain itu, penggunaan teknik transfer learning dengan pretrained model pada data gambar medis juga dapat membantu meningkatkan akurasi model. Pastikan untuk menyelaraskan teknik augmentasi dengan karakteristik data gambar medis MRI untuk hasil yang optimal. Selain itu, perhatikan juga tuning hyperparameter dan validasi lintas ukuran (cross-validation) untuk memperbaiki performa model Anda. Jika Anda memerlukan panduan lebih lanjut atau memiliki pertanyaan tambahan, jangan ragu untuk mengajukan pertanyaan lebih lanjut.
#
#
# --- Konsultasi AI dengan Budi ---
# Budi: Hai, saya Budi. Saya sedang mengerjakan proyek NLP dan ingin memahami bagaimana fine-tuning model BERT.
# AI Consultant: Halo Budi, sepertinya terjadi kesalahan dalam percakapan sebelumnya. Apakah ada pertanyaan baru atau hal lain yang ingin Anda diskusikan tentang fine-tuning model BERT atau topik lain terkait AI? Silakan beri tahu saya, agar saya dapat memberikan bantuan yang lebih tepat dan sesuai dengan kebutuhan Anda.
#
# Budi: Apakah saya perlu banyak data untuk fine-tuning BERT agar mendapatkan hasil optimal?
# AI Consultant: Data yang banyak memang dapat meningkatkan hasil optimal dalam fine-tuning model BERT untuk proyek NLP Anda. Namun, sebaiknya Anda menyesuaikan jumlah data yang diperlukan dengan kompleksitas tugas yang ingin Anda pecahkan. Jika data yang Anda miliki terbatas, Anda masih bisa mencoba fine-tuning BERT dengan dataset yang lebih kecil dan menerapkan teknik seperti data augmentation atau transfer learning untuk membantu meningkatkan performa model. Yang terpenting adalah menjaga keseimbangan antara kebutuhan data dan kompleksitas tugas untuk mencapai hasil yang optimal. Jika Anda memiliki pertanyaan lebih lanjut atau butuh panduan lebih lanjut, jangan ragu untuk bertanya lagi.
#
# Budi: Bagaimana cara mengatasi overfitting pada model NLP saya?
# AI Consultant: Budi, untuk mengatasi overfitting pada model NLP Anda, Anda bisa menerapkan beberapa strategi sebagai berikut:
#
# 1. **Regularisasi**: Gunakan regularisasi seperti L1 atau L2 regularization untuk mencegah model mempelajari pola yang terlalu rumit dari data pelatihan yang hanyalah noise.
#
# 2. **Dropout**: Terapkan teknik dropout pada layer-layer neural network untuk mencegah ketergantungan berlebihan antar neuron yang bisa menyebabkan overfitting.
#
# 3. **Validasi Silang (Cross-validation)**: Gunakan teknik validasi silang untuk membagi data training menjadi subset yang berbeda untuk melatih dan menguji kinerja model. Ini membantu evaluasi model pada data yang tidak terlihat sebelumnya.
#
# 4. **Monitoring Kinerja**: Selalu pantau kinerja model pada data validasi atau uji untuk mendeteksi tanda-tanda overfitting. Jika terjadi overfitting, Anda bisa berhenti melatih model atau menerapkan strategi lain.
#
# 5. **Pengurangan Kapasitas Model**: Kaji apakah model terlalu kompleks untuk data yang Anda miliki. Pertimbangkan untuk mengurangi kompleksitas model dengan mengurangi jumlah parameter, layer, atau ukuran embedding.
#
# Dengan menerapkan strategi ini secara seimbang, Anda dapat mengurangi risiko overfitting pada model NLP Anda. Jika Anda memerlukan panduan lebih lanjut atau memiliki pertanyaan spesifik, jangan ragu untuk bertanya.
#
#
# --- Konsultasi AI dengan Citra ---
# Citra: Selamat siang, saya Citra. Saya ingin memahami bagaimana cara mendeteksi anomali pada data time series.
# AI Consultant: Selamat siang, Citra. Untuk mendeteksi anomali pada data time series, Anda bisa menggunakan pendekatan yang dikenal sebagai anomaly detection pada time series data. Salah satu metode yang umum digunakan adalah dengan menggunakan teknik statistik seperti moving average, exponential smoothing, atau deteksi pencilan (outlier detection). Selain itu, Anda juga dapat menggunakan algoritma machine learning seperti Isolation Forest, One-Class SVM, atau LSTM neural networks untuk mendeteksi pola anomali dalam data time series. Apakah Anda memerlukan bantuan lebih lanjut dalam mengimplementasikan salah satu metode tersebut?
#
# Citra: Apakah Autoencoder cocok untuk mendeteksi anomali pada data keuangan?
# AI Consultant: Ya, Autoencoder adalah salah satu metode yang cocok untuk mendeteksi anomali pada data keuangan. Dalam kasus data keuangan yang kompleks, Autoencoder dapat digunakan untuk mengidentifikasi pola anomali berdasarkan perbedaan dalam rekonstruksi data. Dengan melatih Autoencoder menggunakan data normal, model dapat mengenali anomali sebagai data yang tidak dapat direkonstruksi dengan baik. Autoencoder merupakan pendekatan yang powerful dan sering digunakan dalam deteksi anomali pada data keuangan. Apakah Anda memerlukan bantuan lebih lanjut dalam mengimplementasikan Autoencoder untuk data keuangan?
#
# Citra: Bagaimana cara memilih threshold terbaik untuk mendeteksi anomali?
# AI Consultant: Untuk memilih threshold terbaik dalam mendeteksi anomali, Anda dapat mempertimbangkan beberapa pendekatan, antara lain:
#
# 1. **Metode Statistik**:
#    - Gunakan analisis z-score untuk menentukan threshold berdasarkan deviasi standar dari rata-rata.
#    - Gunakan histogram atau distribusi data untuk menentukan nilai ambang batas.
#
# 2. **Metode Percobaan dan Pengujian**:
#    - Lakukan eksperimen dengan berbagai nilai threshold untuk mengevaluasi kinerja deteksi anomali.
#    - Manfaatkan teknik validasi silang (cross-validation) untuk memastikan kecocokan threshold pada berbagai dataset.
#
# 3. **Metode Machine Learning**:
#    - Gunakan receiver operating characteristic (ROC) curve untuk mengevaluasi kinerja deteksi anomali dengan berbagai threshold.
#    - Perhatikan precision-recall curve untuk memilih threshold optimal, mempertimbangkan keseimbangan antara false positive dan false negative.
#
# Dengan mempertimbangkan pendekatan-pendekatan tersebut, Anda dapat menentukan threshold terbaik untuk mendeteksi anomali dalam data time series. Apakah ada hal lain yang ingin Anda diskusikan lebih lanjut?
#
#
# --- Konsultasi AI dengan Anom ---
# Anom: Selamat Sorem, Saya Anom. Saya ingin melakukan konsultasi mengenai cabcode.id
# AI Consultant: Selamat sore, Anom. Tentu, saya siap membantu Anda. Apa yang ingin Anda diskusikan mengenai Cabcode.id?
#
# Anom: Apa saja yang dapat dilakukan oleh cabcode.id?
# AI Consultant: Cabcode.id adalah sebuah platform yang menyediakan layanan pengenalan barcode dan QR code. Dengan menggunakan cabcode.id, pengguna dapat melakukan scan atau pembacaan barcode dan QR code untuk mendapatkan informasi tertentu yang terkait dengan kode tersebut. Beberapa fungsi yang dapat dilakukan oleh cabcode.id antara lain adalah pengecekan keaslian suatu produk, informasi detail produk, dan bahkan melakukan pembayaran secara instan dengan menggunakan QR code. Apakah Anda tertarik untuk lebih mendalami fitur-fitur cabcode.id, Anom?
#
# Anom: Saya ingin memesan layanan Konsultasi dan tutor di cabcod.id, kiranya layanan seperti apakah itu
# AI Consultant: Selamat malam, Anom. Layanan konsultasi dan tutor yang Anda maksud mungkin bisa memberikan bantuan dalam membimbing pengguna dalam menggunakan platform cabcode.id dengan lebih efisien. Tutor mungkin akan memberikan panduan langkah demi langkah mengenai cara menggunakan fitur-fitur cabcode.id, memberikan tips dan trik terkait penggunaan platform, serta menjawab pertanyaan-pertanyaan pengguna seputar penggunaan cabcode.id. Dengan adanya layanan konsultasi dan tutor, diharapkan pengguna dapat memahami dengan lebih baik cara memanfaatkan potensi dan fitur-fitur yang ditawarkan oleh cabcode.id. Apakah informasi ini dapat membantu Anda, Anom? Apakah ada pertanyaan lain yang ingin Anda ajukan?
#
#
# --- Ringkasan konsultasi Andi ---
# 1. U-Net merupakan salah satu arsitektur yang efektif untuk segmentasi MRI, namun untuk memastikan kesesuaian dengan kebutuhan Anda, disarankan untuk melakukan evaluasi terhadap arsitektur lain.
# 2. Teknik augmentasi data seperti rotasi, pergeseran, zoom, dan lainnya dapat meningkatkan akurasi model Anda, namun pertimbangkan juga teknik lain seperti cutout atau random cropping sesuai dengan karakteristik data MRI.
# 3. Gunakan transfer learning dengan pretrained model dan penting untuk tuning hyperparameter serta validasi lintas ukuran untuk meningkatkan performa model Anda. Jika perlu bantuan lebih lanjut, jangan ragu untuk bertanya.
#
# --- Ringkasan konsultasi Budi ---
# Halo Budi, dalam fine-tuning model BERT sebaiknya Anda menyesuaikan jumlah data dengan kompleksitas tugas yang ingin Anda pecahkan. Lebih banyak data cenderung memberikan hasil yang lebih baik, namun Anda juga dapat mencoba fine-tuning dengan dataset yang lebih kecil dan menerapkan teknik lain seperti data augmentation atau transfer learning. Untuk mengatasi overfitting pada model NLP, Anda dapat menggunakan regularisasi, dropout, validasi silang, monitoring kinerja, dan mengurangi kapasitas model. Dengan menerapkan strategi ini secara seimbang, Anda dapat mengurangi risiko overfitting dan meningkatkan performa model Anda. Jika Anda membutuhkan panduan lebih lanjut, jangan ragu untuk bertanya lagi.
#
# --- Ringkasan konsultasi Citra ---
# 1. Autoencoder adalah metode yang cocok untuk mendeteksi anomali pada data keuangan karena dapat mengidentifikasi pola anomali berdasarkan rekonstruksi data.
# 2. Dalam memilih threshold terbaik untuk mendeteksi anomali, Anda dapat gunakan metode statistik, percobaan dan pengujian, serta machine learning untuk menentukan nilai threshold yang optimal.
#
# Apakah ada pertanyaan lain yang ingin Anda ajukan?
#
# --- Ringkasan konsultasi Anom ---
# Cabcode.id adalah platform yang menyediakan layanan pengenalan barcode dan QR code, seperti pengecekan keaslian produk, informasi detail produk, dan pembayaran instan dengan QR code. Layanan konsultasi dan tutor di cabcode.id mungkin memberikan bantuan dalam membimbing pengguna menggunakan platform dengan efisien, memberikan panduan, tips, trik, dan menjawab pertanyaan pengguna seputar penggunaan platform. Semoga informasi ini bermanfaat untuk Anda, Anom. Apakah ada hal lain yang ingin Anda tanyakan?
